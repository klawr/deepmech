# %% [markdown]
# ## experimenting...

# %%
from os.path import join

raw = join('data', 'raw')
processed = join('data', 'processed')

from src.training_env import reset_and_populate, populate

reset_and_populate(raw, processed, [300,100,100])
# Out:
# ['data\\processed\\train\\n',
#  'data\\processed\\validation\\n',
#  'data\\processed\\test\\n',
#  'data\\processed\\train\\o',
#  'data\\processed\\validation\\o',
#  'data\\processed\\test\\o',
#  'data\\processed\\train\\x',
#  'data\\processed\\validation\\x',
#  'data\\processed\\test\\x']

# %% [markdown]
# ## Data generator

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def create_generator(data_dir, batch_size, datagen):
    full_path = join(processed, data_dir)
    return datagen.flow_from_directory(
        full_path,
        target_size=(32, 32),
        color_mode='grayscale',
        batch_size=batch_size,
        class_mode='binary')

# train and validation generator are virtually the same, but is still defined in good taste

train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=360,
        horizontal_flip=True,
        vertical_flip=True)

validation_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=360,
        horizontal_flip=True,
        vertical_flip=True)

test_datagen = ImageDataGenerator(rescale = 1./255)

train_generator = create_generator('train', 10, train_datagen)
validation_generator = create_generator('validation', 10, validation_datagen)
test_generator = create_generator('test', 10, test_datagen)
# Out:
# Found 900 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.

# %% [markdown]
# ## Create Model
#
# Below a model defining function is defined.
# The function creates a model with:
# - n layers (between 2 and 5)
# -

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import SGD, RMSprop

def create_model(hp):
    model = models.Sequential()
    # Invariant Input
    model.add(layers.Flatten(input_shape=(32, 32, 1)))
    # Add n layers
    for i in range(hp.Int('num_layers', 2, 5)):
        model.add(layers.Dense(
            units=hp.Int('num_nodes', 16, 64, 4),
            activation='relu'))
    # Invariant Output
    model.add(layers.Dense(3, 'softmax'))
    # Select any Optimizer
    optimizers = {
        'sgd': SGD(
            lr=hp.Choice('learning_rate', [0.001, 0.003, 0.007, 0.01]),
            momentum=hp.Float('momentum', 0.5, 1, 0.1),
            nesterov=hp.Boolean('nesterov'))
    }
    # Compile Model
    model.compile(
        loss='sparse_categorical_crossentropy',
        optimizer=optimizers[hp.Choice('optimizer', ['sgd'])],
        metrics=['acc'])

    return model

# %% [markdown]
# ## Custom KerasTuner Class
#
# Create a subclass to implement features for visualization of the

# %%
from datetime import datetime
from tensorboard.plugins.hparams import api
from kerastuner import RandomSearch
from tensorflow import summary
from tensorflow.keras.callbacks import TensorBoard

class customTuner(RandomSearch):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

    def run_trial(self, trial, *args, **kwargs):
        callbacks = kwargs.pop('callbacks', [])
        callbacks = self._deepcopy_callbacks(callbacks)
        trial_dir = self.get_trial_dir(trial.trial_id)
        callbacks.append(TensorBoard(trial_dir))
        kwargs['callbacks'] = callbacks
        super().run_trial(trial, *args, **kwargs)

    def on_trial_end(self, trial):
        trial_dir = self.get_trial_dir(trial.trial_id)
        # put the hparams where the metrics of tensorboard are
        hparam_dir = join(trial_dir, trial.trial_id, 'execution0', 'train')
        hparams = trial.hyperparameters.values
        with summary.create_file_writer(hparam_dir).as_default():
            api.hparams(hparams, trial_id=trial.trial_id)
        print(datetime.now().strftime("%Y-%m-%dT%H-%M-%S"))
        print('Remaining Trials: ' + str(self.remaining_trials))
        super().on_trial_end(trial)

    def on_epoch_end(self, trial, model, epoch, logs):
        trial_dir = self.get_trial_dir(trial.trial_id)
        # put the data where the metrics of tensorboard are
        hist_dir = join(trial_dir, trial.trial_id, 'execution0', 'train')
        with summary.create_file_writer(hist_dir).as_default():
            for layer in model.weights:
                summary.histogram(layer.name, data=layer, step=epoch)
        super().on_epoch_end(trial, model, epoch, logs)

# %%
from kerastuner import HyperParameters

hp=HyperParameters()
log_dir = join('logs', 'srp13')
timestamp = datetime.now().strftime("%Y-%m-%dT%H-%M-%S")

tuner = customTuner(
    create_model,
    hyperparameters=hp,
    objective='acc',
    max_trials=500,
    executions_per_trial=1,
    directory=log_dir,
    project_name=timestamp)

tuner.search_space_summary()
# Out:
# <span style="color:#4527A0"><h1 style="font-size:18px">Search space summary</h1></span>
# <span style="color:cyan"> |-Default search space size: 6</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">num_layers (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 5</span>
# <span style="color:cyan"> |-min_value: 2</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 1</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">num_nodes (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 64</span>
# <span style="color:cyan"> |-min_value: 16</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 4</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">learning_rate (Choice)</h2></span>
# <span style="color:cyan"> |-default: 0.001</span>
# <span style="color:blue"> |-ordered: True</span>
# <span style="color:cyan"> |-values: [0.001, 0.003, 0.007, 0.01]</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">momentum (Float)</h2></span>
# <span style="color:cyan"> |-default: 0.5</span>
# <span style="color:blue"> |-max_value: 1.0</span>
# <span style="color:cyan"> |-min_value: 0.5</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 0.1</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">nesterov (Boolean)</h2></span>
# <span style="color:cyan"> |-default: False</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">optimizer (Choice)</h2></span>
# <span style="color:cyan"> |-default: sgd</span>
# <span style="color:blue"> |-ordered: False</span>
# <span style="color:cyan"> |-values: ['sgd']</span>

# %%
from tensorflow.keras.callbacks import EarlyStopping

callbacks = [ EarlyStopping(monitor='loss', patience=3) ]

tuner.search(
    train_generator,
    validation_data=validation_generator,
    epochs=30,
    steps_per_epoch=30,
    validation_steps=30,
    verbose=0,
    callbacks=callbacks)
# Out:
# Remaining Trials: 499
# Remaining Trials: 498
# Remaining Trials: 497
# Remaining Trials: 496
# Remaining Trials: 495
# Remaining Trials: 494
# Remaining Trials: 493
# Remaining Trials: 492
# Remaining Trials: 491
# Remaining Trials: 490
# Remaining Trials: 489
# Remaining Trials: 488
# Remaining Trials: 487
# Remaining Trials: 486
# Remaining Trials: 485
# Remaining Trials: 484
# Remaining Trials: 483
# Remaining Trials: 482
# Remaining Trials: 481
# Remaining Trials: 480
# Remaining Trials: 479
# Remaining Trials: 478
# Remaining Trials: 477
# Remaining Trials: 476
# Remaining Trials: 475
# Remaining Trials: 474
# Remaining Trials: 473
# Remaining Trials: 472
# Remaining Trials: 471
# Remaining Trials: 470
# Remaining Trials: 469
# Remaining Trials: 468
# Remaining Trials: 467
# Remaining Trials: 466
# Remaining Trials: 465
# Remaining Trials: 464
# Remaining Trials: 463
# Remaining Trials: 462
# Remaining Trials: 461
# Remaining Trials: 460
# Remaining Trials: 459
# Remaining Trials: 458
# Remaining Trials: 457
# Remaining Trials: 456
# Remaining Trials: 455
# Remaining Trials: 454
# Remaining Trials: 453
# Remaining Trials: 452
# Remaining Trials: 451
# Remaining Trials: 450
# Remaining Trials: 449
# Remaining Trials: 448
# Remaining Trials: 447
# Remaining Trials: 446
# Remaining Trials: 445
# Remaining Trials: 444
# Remaining Trials: 443
# Remaining Trials: 442
# Remaining Trials: 441
# Remaining Trials: 440
# Remaining Trials: 439
# Remaining Trials: 438
# Remaining Trials: 437
# Remaining Trials: 436
# Remaining Trials: 435
# Remaining Trials: 434
# Remaining Trials: 433
# Remaining Trials: 432
# Remaining Trials: 431
# Remaining Trials: 430
# Remaining Trials: 429
# Remaining Trials: 428
# Remaining Trials: 427
# Remaining Trials: 426
# Remaining Trials: 425
# Remaining Trials: 424
# Remaining Trials: 423
# Remaining Trials: 422
# Remaining Trials: 421
# Remaining Trials: 420
# Remaining Trials: 419
# Remaining Trials: 418
# Remaining Trials: 417
# Remaining Trials: 416
# Remaining Trials: 415
# Remaining Trials: 414
# Remaining Trials: 413
# Remaining Trials: 412
# Remaining Trials: 411
# Remaining Trials: 410
# Remaining Trials: 409
# Remaining Trials: 408
# Remaining Trials: 407
# Remaining Trials: 406
# Remaining Trials: 405
# Remaining Trials: 404
# Remaining Trials: 403
# Remaining Trials: 402
# Remaining Trials: 401
# Remaining Trials: 400
# Remaining Trials: 399
# Remaining Trials: 398
# Remaining Trials: 397
# Remaining Trials: 396
# Remaining Trials: 395
# Remaining Trials: 394
# Remaining Trials: 393
# Remaining Trials: 392
# Remaining Trials: 391
# Remaining Trials: 390
# Remaining Trials: 389
# Remaining Trials: 388
# Remaining Trials: 387
# Remaining Trials: 386
# Remaining Trials: 385
# Remaining Trials: 384
# Remaining Trials: 383
# Remaining Trials: 382
# Remaining Trials: 381
# Remaining Trials: 380
# Remaining Trials: 379
# Remaining Trials: 378
# Remaining Trials: 377
# Remaining Trials: 376
# Remaining Trials: 375
# Remaining Trials: 374
# Remaining Trials: 373
# Remaining Trials: 372
# Remaining Trials: 371
# Remaining Trials: 370
# Remaining Trials: 369
# Remaining Trials: 368
# Remaining Trials: 367
# Remaining Trials: 366
# Remaining Trials: 365
# Remaining Trials: 364
# Remaining Trials: 363
# Remaining Trials: 362
# Remaining Trials: 361
# Remaining Trials: 360
# Remaining Trials: 359
# Remaining Trials: 358
# Remaining Trials: 357
# Remaining Trials: 356
# Remaining Trials: 355
# Remaining Trials: 354
# Remaining Trials: 353
# Remaining Trials: 352
# Remaining Trials: 351
# Remaining Trials: 350
# Remaining Trials: 349
# Remaining Trials: 348
# Remaining Trials: 347
# Remaining Trials: 346
# Remaining Trials: 345
# Remaining Trials: 344
# Remaining Trials: 343
# Remaining Trials: 342
# Remaining Trials: 341
# Remaining Trials: 340
# Remaining Trials: 339
# Remaining Trials: 338
# Remaining Trials: 337
# Remaining Trials: 336
# Remaining Trials: 335
# Remaining Trials: 334
# Remaining Trials: 333
# Remaining Trials: 332
# Remaining Trials: 331
# Remaining Trials: 330
# Remaining Trials: 329
# Remaining Trials: 328
# Remaining Trials: 327
# Remaining Trials: 326
# Remaining Trials: 325
# Remaining Trials: 324
# Remaining Trials: 323
# Remaining Trials: 322
# Remaining Trials: 321
# Remaining Trials: 320
# Remaining Trials: 319
# Remaining Trials: 318
# Remaining Trials: 317
# Remaining Trials: 316
# Remaining Trials: 315
# Remaining Trials: 314
# Remaining Trials: 313
# Remaining Trials: 312
# Remaining Trials: 311
# Remaining Trials: 310
# Remaining Trials: 309
# Remaining Trials: 308
# Remaining Trials: 307
# Remaining Trials: 306
# Remaining Trials: 305
# Remaining Trials: 304
# Remaining Trials: 303
# Remaining Trials: 302
# Remaining Trials: 301
# Remaining Trials: 300
# Remaining Trials: 299
# Remaining Trials: 298
# Remaining Trials: 297
# Remaining Trials: 296
# Remaining Trials: 295
# Remaining Trials: 294
# Remaining Trials: 293
# Remaining Trials: 292
# Remaining Trials: 291
# Remaining Trials: 290
# Remaining Trials: 289
# Remaining Trials: 288
# Remaining Trials: 287
# Remaining Trials: 286
# Remaining Trials: 285
# Remaining Trials: 284
# Remaining Trials: 283
# Remaining Trials: 282
# Remaining Trials: 281
# Remaining Trials: 280
# Remaining Trials: 279
# Remaining Trials: 278
# Remaining Trials: 277
# Remaining Trials: 276
# Remaining Trials: 275
# Remaining Trials: 274
# Remaining Trials: 273
# Remaining Trials: 272
# Remaining Trials: 271
# Remaining Trials: 270
# Remaining Trials: 269
# Remaining Trials: 268
# Remaining Trials: 267
# Remaining Trials: 266
# Remaining Trials: 265
# Remaining Trials: 264
# Remaining Trials: 263
# Remaining Trials: 262
# Remaining Trials: 261
# Remaining Trials: 260
# Remaining Trials: 259
# Remaining Trials: 258
# Remaining Trials: 257
# Remaining Trials: 256
# Remaining Trials: 255
# Remaining Trials: 254
# Remaining Trials: 253
# Remaining Trials: 252
# Remaining Trials: 251
# Remaining Trials: 250
# Remaining Trials: 249
# Remaining Trials: 248
# Remaining Trials: 247
# Remaining Trials: 246
# Remaining Trials: 245
# Remaining Trials: 244
# Remaining Trials: 243
# Remaining Trials: 242
# Remaining Trials: 241
# Remaining Trials: 240
# Remaining Trials: 239
# Remaining Trials: 238
# Remaining Trials: 237
# Remaining Trials: 236
# Remaining Trials: 235
# Remaining Trials: 234
# Remaining Trials: 233
# Remaining Trials: 232
# Remaining Trials: 231
# Remaining Trials: 230
# Remaining Trials: 229
# Remaining Trials: 228
# Remaining Trials: 227
# Remaining Trials: 226
# Remaining Trials: 225
# Remaining Trials: 224
# Remaining Trials: 223
# Remaining Trials: 222
# Remaining Trials: 221
# Remaining Trials: 220
# Remaining Trials: 219
# Remaining Trials: 218
# Remaining Trials: 217
# Remaining Trials: 216
# Remaining Trials: 215
# Remaining Trials: 214
# Remaining Trials: 213
# Remaining Trials: 212
# Remaining Trials: 211
# Remaining Trials: 210
# Remaining Trials: 209
# Remaining Trials: 208
# Remaining Trials: 207
# Remaining Trials: 206
# Remaining Trials: 205
# Remaining Trials: 204
# Remaining Trials: 203
# Remaining Trials: 202
# Remaining Trials: 201
# Remaining Trials: 200
# Remaining Trials: 199
# Remaining Trials: 198
# Remaining Trials: 197
# Remaining Trials: 196
# Remaining Trials: 195
# Remaining Trials: 194
# Remaining Trials: 193
# Remaining Trials: 192
# Remaining Trials: 191
# Remaining Trials: 190
# Remaining Trials: 189
# Remaining Trials: 188
# Remaining Trials: 187
# Remaining Trials: 186
# Remaining Trials: 185
# Remaining Trials: 184
# Remaining Trials: 183
# Remaining Trials: 182
# Remaining Trials: 181
# Remaining Trials: 180
# Remaining Trials: 179
# Remaining Trials: 178
# Remaining Trials: 177
# Remaining Trials: 176
# Remaining Trials: 175
# Remaining Trials: 174
# Remaining Trials: 173
# Remaining Trials: 172
# Remaining Trials: 171
# Remaining Trials: 170
# Remaining Trials: 169
# Remaining Trials: 168
# Remaining Trials: 167
# Remaining Trials: 166
# Remaining Trials: 165
# Remaining Trials: 164
# Remaining Trials: 163
# Remaining Trials: 162
# Remaining Trials: 161
# Remaining Trials: 160
# Remaining Trials: 159
# Remaining Trials: 158
# Remaining Trials: 157
# Remaining Trials: 156
# Remaining Trials: 155
# Remaining Trials: 154
# Remaining Trials: 153
# Remaining Trials: 152
# Remaining Trials: 151
# Remaining Trials: 150
# Remaining Trials: 149
# Remaining Trials: 148
# Remaining Trials: 147
# Remaining Trials: 146
# Remaining Trials: 145
# Remaining Trials: 144
# Remaining Trials: 143
# Remaining Trials: 142
# Remaining Trials: 141
# Remaining Trials: 140
# Remaining Trials: 139
# Remaining Trials: 138
# Remaining Trials: 137
# Remaining Trials: 136
# Remaining Trials: 135
# Remaining Trials: 134
# Remaining Trials: 133
# Remaining Trials: 132
# Remaining Trials: 131
# Remaining Trials: 130
# Remaining Trials: 129
# Remaining Trials: 128
# Remaining Trials: 127
# Remaining Trials: 126
# Remaining Trials: 125
# Remaining Trials: 124
# Remaining Trials: 123
# Remaining Trials: 122
# Remaining Trials: 121
# Remaining Trials: 120
# Remaining Trials: 119
# Remaining Trials: 118
# Remaining Trials: 117
# Remaining Trials: 116
# Remaining Trials: 115
# Remaining Trials: 114
# Remaining Trials: 113
# Remaining Trials: 112
# Remaining Trials: 111
# Remaining Trials: 110
# Remaining Trials: 109
# Remaining Trials: 108
# Remaining Trials: 107
# Remaining Trials: 106
# Remaining Trials: 105
# Remaining Trials: 104
# Remaining Trials: 103
# Remaining Trials: 102
# Remaining Trials: 101
# Remaining Trials: 100
# Remaining Trials: 99
# Remaining Trials: 98
# Remaining Trials: 97
# Remaining Trials: 96
# Remaining Trials: 95
# Remaining Trials: 94
# Remaining Trials: 93
# Remaining Trials: 92
# Remaining Trials: 91
# Remaining Trials: 90
# Remaining Trials: 89
# Remaining Trials: 88
# Remaining Trials: 87
# Remaining Trials: 86
# Remaining Trials: 85
# Remaining Trials: 84
# Remaining Trials: 83
# Remaining Trials: 82
# Remaining Trials: 81
# Remaining Trials: 80
# Remaining Trials: 79
# Remaining Trials: 78
# Remaining Trials: 77
# Remaining Trials: 76
# Remaining Trials: 75
# Remaining Trials: 74
# Remaining Trials: 73
# Remaining Trials: 72
# Remaining Trials: 71
# Remaining Trials: 70
# Remaining Trials: 69
# Remaining Trials: 68
# Remaining Trials: 67
# Remaining Trials: 66
# Remaining Trials: 65
# Remaining Trials: 64
# Remaining Trials: 63
# Remaining Trials: 62
# Remaining Trials: 61
# Remaining Trials: 60
# Remaining Trials: 59
# Remaining Trials: 58
# Remaining Trials: 57
# Remaining Trials: 56
# Remaining Trials: 55
# Remaining Trials: 54
# Remaining Trials: 53
# Remaining Trials: 52
# Remaining Trials: 51
# Remaining Trials: 50
# Remaining Trials: 49
# Remaining Trials: 48
# Remaining Trials: 47
# Remaining Trials: 46
# Remaining Trials: 45
# Remaining Trials: 44
# Remaining Trials: 43
# Remaining Trials: 42
# Remaining Trials: 41
# Remaining Trials: 40
# Remaining Trials: 39
# Remaining Trials: 38
# Remaining Trials: 37
# Remaining Trials: 36
# Remaining Trials: 35
# Remaining Trials: 34
# Remaining Trials: 33
# Remaining Trials: 32
# Remaining Trials: 31
# Remaining Trials: 30
# Remaining Trials: 29
# Remaining Trials: 28
# Remaining Trials: 27
# Remaining Trials: 26
# Remaining Trials: 25
# Remaining Trials: 24
# Remaining Trials: 23
# Remaining Trials: 22
# Remaining Trials: 21
# Remaining Trials: 20
# Remaining Trials: 19
# Remaining Trials: 18
# Remaining Trials: 17
# Remaining Trials: 16
# Remaining Trials: 15
# Remaining Trials: 14
# Remaining Trials: 13
# Remaining Trials: 12
# Remaining Trials: 11
# Remaining Trials: 10
# Remaining Trials: 9
# Remaining Trials: 8
# Remaining Trials: 7
# Remaining Trials: 6
# Remaining Trials: 5
# Remaining Trials: 4
# Remaining Trials: 3
# Remaining Trials: 2
# Remaining Trials: 1
# Remaining Trials: 0
# INFO:tensorflow:Oracle triggered exit
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 44</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7633333206176758</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 2</span>
# <span style="color:cyan"> |-num_nodes: 52</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7566666603088379</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.8999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 28</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.8199999928474426</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.8999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 56</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.5733333230018616</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 28</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.8199999928474426</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 16</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.40666666626930237</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.5</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 20</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.6000000238418579</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.5</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 48</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7333333492279053</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 64</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.653333306312561</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.5</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 5</span>
# <span style="color:cyan"> |-num_nodes: 48</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7799999713897705</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.7</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 2</span>
# <span style="color:cyan"> |-num_nodes: 40</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.8133333325386047</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 2</span>
# <span style="color:cyan"> |-num_nodes: 40</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7166666388511658</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.8999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 16</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.3633333444595337</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.5</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 5</span>
# <span style="color:cyan"> |-num_nodes: 24</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.36666667461395264</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 44</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.746666669845581</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 20</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7666666507720947</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.9999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 56</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.36666667461395264</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 60</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7566666603088379</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 40</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7900000214576721</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.8999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 2</span>
# <span style="color:cyan"> |-num_nodes: 36</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.6899999976158142</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 5</span>
# <span style="color:cyan"> |-num_nodes: 56</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.44999998807907104</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.7</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 24</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.4633333384990692</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.7</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 5</span>
# <span style="color:cyan"> |-num_nodes: 16</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.41333332657814026</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.7</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 24</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.5866666436195374</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 56</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7266666889190674</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 5</span>
# <span style="color:cyan"> |-num_nodes: 24</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.47333332896232605</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 20</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.38333332538604736</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 24</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.3700000047683716</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 5</span>
# <span style="color:cyan"> |-num_nodes: 60</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7599999904632568</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.8999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 28</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.5299999713897705</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 32</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.8166666626930237</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 52</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7900000214576721</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.7</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 36</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7699999809265137</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.8999999999999999</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 16</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.5533333420753479</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 2</span>
# <span style="color:cyan"> |-num_nodes: 52</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7866666913032532</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.8999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 48</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.6133333444595337</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.7</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 28</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.6733333468437195</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 40</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.8199999928474426</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 56</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.6466666460037231</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 36</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7799999713897705</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.8999999999999999</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 28</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.8333333134651184</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.9999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 5</span>
# <span style="color:cyan"> |-num_nodes: 40</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.5199999809265137</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.8999999999999999</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 2</span>
# <span style="color:cyan"> |-num_nodes: 16</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.4933333396911621</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 20</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7833333611488342</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 44</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.4266666769981384</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 40</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7933333516120911</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.8999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 32</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7099999785423279</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.8999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 5</span>
# <span style="color:cyan"> |-num_nodes: 36</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.39666667580604553</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.5</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 2</span>
# <span style="color:cyan"> |-num_nodes: 60</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.653333306312561</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 32</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.4099999964237213</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.5</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 44</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.746666669845581</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.7</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 28</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.3466666638851166</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 5</span>
# <span style="color:cyan"> |-num_nodes: 24</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.41333332657814026</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.7</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 60</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.75</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.7</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 48</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7799999713897705</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 16</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.5066666603088379</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# ...
# <span style="color:cyan"> |-Score: 0.7733333110809326</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.8999999999999999</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 20</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.8066666722297668</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.8999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 2</span>
# <span style="color:cyan"> |-num_nodes: 28</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.6899999976158142</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.7</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 20</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.3700000047683716</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 16</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.3866666555404663</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 32</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.40666666626930237</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 5</span>
# <span style="color:cyan"> |-num_nodes: 52</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.6000000238418579</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 56</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7400000095367432</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.5</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 24</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.3799999952316284</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 48</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.70333331823349</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 40</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7633333206176758</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 2</span>
# <span style="color:cyan"> |-num_nodes: 48</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7933333516120911</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.7</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 2</span>
# <span style="color:cyan"> |-num_nodes: 52</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.5366666913032532</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 56</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.44333332777023315</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.9999999999999999</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 60</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7266666889190674</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 5</span>
# <span style="color:cyan"> |-num_nodes: 28</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7300000190734863</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.9999999999999999</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 60</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.3700000047683716</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.7</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 28</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.5</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.7</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 44</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.5366666913032532</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 5</span>
# <span style="color:cyan"> |-num_nodes: 28</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.36000001430511475</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 24</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.6566666960716248</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.7</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 48</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7099999785423279</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 4</span>
# <span style="color:cyan"> |-num_nodes: 36</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.6033333539962769</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.6</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_layers: 3</span>
# <span style="color:cyan"> |-num_nodes: 20</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.7333333492279053</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-momentum: 0.9999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_layers: 2</span>
# <span style="color:cyan"> |-num_nodes: 56</span>
# <span style="color:blue"> |-optimizer: sgd</span>
# <span style="color:cyan"> |-Score: 0.4166666567325592</span>
# <span style="color:cyan"> |-Best step: 0</span>

# %%
tuner.results_summary()
