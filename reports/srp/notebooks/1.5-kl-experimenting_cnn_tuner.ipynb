# %% [markdown]
# ## experimenting...

# %%
from os.path import join

raw = join('data', 'raw')
processed = join('data', 'processed')

from src.training_env import reset_and_populate, populate

reset_and_populate(raw, processed, [400,100,0])
# Out:
# ['data\\processed\\train\\n',
#  'data\\processed\\validation\\n',
#  'data\\processed\\test\\n',
#  'data\\processed\\train\\o',
#  'data\\processed\\validation\\o',
#  'data\\processed\\test\\o',
#  'data\\processed\\train\\x',
#  'data\\processed\\validation\\x',
#  'data\\processed\\test\\x']

# %% [markdown]
# ## Data generator

# %%
import tensorflow as tf
import numpy as np
from os.path import sep
import pathlib

def create_generator(data_dir, batch_size=32, shuffle_buffer_size=1000):
        def get_label(file_path):
                parts = tf.strings.split(file_path, sep)
                return parts[-2] == labels

        def decode_img(img):
                img = tf.image.decode_png(img, channels=1)
                img = tf.image.convert_image_dtype(img, tf.float32)
                return tf.image.resize(img, [32, 32])

        def process_path(file_path):
                label = get_label(file_path)
                img = tf.io.read_file(file_path)
                img = decode_img(img)
                return img, label

        data_dir = pathlib.Path(data_dir)
        labels = np.array([item.name for item in data_dir.glob('*')])
        autotune = tf.data.experimental.AUTOTUNE

        dataset = (tf.data.Dataset.list_files(str(data_dir/'*/*'))
                .map(process_path, num_parallel_calls=autotune)
                .cache()
                .shuffle(shuffle_buffer_size)
                .repeat()
                .batch(batch_size)
                .prefetch(buffer_size=autotune))
        return dataset

train_generator = create_generator(join(processed, 'train'), 20)
validation_generator = create_generator(join(processed, 'validation'), 10)

# %% [markdown]
# ## Create model

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adadelta, Adam, RMSprop, SGD

def create_model(hp):
    model = models.Sequential()
    model.add(layers.Conv2D(hp.Int(
        'num_filter_0', 16, 64, 16), (4,4) ,activation='relu', input_shape=(32, 32, 1)))

    for i in range(hp.Int('num_cnn_layers', 1, 4)):
        filter = hp.Int('num_filter_' + str(i), 16, 128, 16)
        model.add(layers.Conv2D(filter, (4,4), activation='relu', padding='same'))
        if hp.Boolean('pooling_' + str(i)):
            model.add(layers.MaxPooling2D(2, 2))

    model.add(layers.Flatten())
    for i in range(hp.Int('num_dense_layers', 1, 3)):
        nodes = hp.Int('num_nodes_' + str(i), 16, 64, 4)
        model.add(layers.Dense(nodes, activation='relu'))
    
    model.add(layers.Dense(3, 'softmax'))

    optimizer = SGD(
            lr=hp.Choice('learning_rate', [0.001, 0.003, 0.007, 0.01, 0.03]),
            momentum=hp.Float('momentum', 0.6, 1, 0.1),
            nesterov=hp.Boolean('nesterov'))

    model.compile(
        loss='categorical_crossentropy',
        optimizer=optimizer,
        metrics=['acc'])

    return model

# %%
from datetime import datetime
from tensorboard.plugins.hparams import api
from kerastuner import RandomSearch
from tensorflow import summary
from tensorflow.keras.callbacks import TensorBoard

class customTuner(RandomSearch):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

    def run_trial(self, trial, *args, **kwargs):
        callbacks = kwargs.pop('callbacks', [])
        callbacks = self._deepcopy_callbacks(callbacks)
        trial_dir = self.get_trial_dir(trial.trial_id)
        callbacks.append(TensorBoard(trial_dir))
        kwargs['callbacks'] = callbacks
        super().run_trial(trial, *args, **kwargs)

    def on_trial_end(self, trial):
        trial_dir = self.get_trial_dir(trial.trial_id)
        # put the hparams where the metrics of tensorboard are
        hparam_dir = join(trial_dir, trial.trial_id, 'execution0', 'train')
        hparams = trial.hyperparameters.values
        with summary.create_file_writer(hparam_dir).as_default():
            api.hparams(hparams, trial_id=trial.trial_id)
        print(datetime.now().strftime("%Y-%m-%dT%H-%M-%S"))
        print('Remaining Trials: ' + str(self.remaining_trials))
        super().on_trial_end(trial)

    def on_epoch_end(self, trial, model, epoch, logs):
        trial_dir = self.get_trial_dir(trial.trial_id)
        # put the data where the metrics of tensorboard are
        hist_dir = join(trial_dir, trial.trial_id, 'execution0', 'train')
        with summary.create_file_writer(hist_dir).as_default():
            for layer in model.weights:
                summary.histogram(layer.name, data=layer, step=epoch)
        super().on_epoch_end(trial, model, epoch, logs)

# %%
from kerastuner import HyperParameters

hp=HyperParameters()
log_dir = 'trial3_logs'
timestamp = datetime.now().strftime("%Y-%m-%dT%H-%M-%S")

tuner = customTuner(
    create_model,
    hyperparameters=hp,
    objective='acc',
    max_trials=5,
    executions_per_trial=1,
    directory=log_dir,
    project_name=timestamp)

tuner.search_space_summary()
# Out:
# <span style="color:#4527A0"><h1 style="font-size:18px">Search space summary</h1></span>
# <span style="color:cyan"> |-Default search space size: 8</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">num_filter_0 (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 64</span>
# <span style="color:cyan"> |-min_value: 16</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 16</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">num_cnn_layers (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 4</span>
# <span style="color:cyan"> |-min_value: 1</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 1</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">pooling_0 (Boolean)</h2></span>
# <span style="color:cyan"> |-default: False</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">num_dense_layers (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 3</span>
# <span style="color:cyan"> |-min_value: 1</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 1</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">num_nodes_0 (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 64</span>
# <span style="color:cyan"> |-min_value: 16</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 4</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">learning_rate (Choice)</h2></span>
# <span style="color:cyan"> |-default: 0.001</span>
# <span style="color:blue"> |-ordered: True</span>
# <span style="color:cyan"> |-values: [0.001, 0.003, 0.007, 0.01, 0.03]</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">momentum (Float)</h2></span>
# <span style="color:cyan"> |-default: 0.6</span>
# <span style="color:blue"> |-max_value: 1.0</span>
# <span style="color:cyan"> |-min_value: 0.6</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 0.1</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">nesterov (Boolean)</h2></span>
# <span style="color:cyan"> |-default: False</span>

# %%
from tensorflow.keras.callbacks import EarlyStopping

callbacks = [ EarlyStopping(monitor='loss', patience=3) ]

tuner.search(
    train_generator,
    validation_data=validation_generator,
    epochs=30,
    steps_per_epoch=30,
    validation_steps=30,
    verbose=0,
    callbacks=callbacks)
# Out:
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.170565). Check your callbacks.
# 2019-11-19T11-50-02
# Remaining Trials: 4
# 2019-11-19T11-50-06
# Remaining Trials: 3
# 2019-11-19T11-50-20
# Remaining Trials: 2
# 2019-11-19T11-50-29
# Remaining Trials: 1
# 2019-11-19T11-50-35
# Remaining Trials: 0
# INFO:tensorflow:Oracle triggered exit
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-momentum: 0.7</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_cnn_layers: 2</span>
# <span style="color:cyan"> |-num_dense_layers: 2</span>
# <span style="color:blue"> |-num_filter_0: 64</span>
# <span style="color:cyan"> |-num_filter_1: 16</span>
# <span style="color:blue"> |-num_nodes_0: 28</span>
# <span style="color:cyan"> |-num_nodes_1: 16</span>
# <span style="color:blue"> |-pooling_0: True</span>
# <span style="color:cyan"> |-pooling_1: False</span>
# <span style="color:cyan"> |-Score: 0.7316666841506958</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.03</span>
# <span style="color:blue"> |-momentum: 0.8999999999999999</span>
# <span style="color:cyan"> |-nesterov: True</span>
# <span style="color:blue"> |-num_cnn_layers: 1</span>
# <span style="color:cyan"> |-num_dense_layers: 2</span>
# <span style="color:blue"> |-num_filter_0: 32</span>
# <span style="color:cyan"> |-num_filter_1: 128</span>
# <span style="color:blue"> |-num_nodes_0: 28</span>
# <span style="color:cyan"> |-num_nodes_1: 20</span>
# <span style="color:blue"> |-pooling_0: False</span>
# <span style="color:cyan"> |-pooling_1: False</span>
# <span style="color:cyan"> |-Score: 0.5099999904632568</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.7999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_cnn_layers: 3</span>
# <span style="color:cyan"> |-num_dense_layers: 2</span>
# <span style="color:blue"> |-num_filter_0: 32</span>
# <span style="color:cyan"> |-num_filter_1: 64</span>
# <span style="color:blue"> |-num_filter_2: 16</span>
# <span style="color:cyan"> |-num_nodes_0: 40</span>
# <span style="color:blue"> |-num_nodes_1: 36</span>
# <span style="color:cyan"> |-pooling_0: True</span>
# <span style="color:blue"> |-pooling_1: True</span>
# <span style="color:cyan"> |-pooling_2: False</span>
# <span style="color:cyan"> |-Score: 0.9566666483879089</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.003</span>
# <span style="color:blue"> |-momentum: 0.9999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_cnn_layers: 2</span>
# <span style="color:cyan"> |-num_dense_layers: 2</span>
# <span style="color:blue"> |-num_filter_0: 64</span>
# <span style="color:cyan"> |-num_filter_1: 64</span>
# <span style="color:blue"> |-num_filter_2: 32</span>
# <span style="color:cyan"> |-num_nodes_0: 60</span>
# <span style="color:blue"> |-num_nodes_1: 20</span>
# <span style="color:cyan"> |-pooling_0: False</span>
# <span style="color:blue"> |-pooling_1: True</span>
# <span style="color:cyan"> |-pooling_2: True</span>
# <span style="color:cyan"> |-Score: 0.8600000143051147</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hp values:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.007</span>
# <span style="color:blue"> |-momentum: 0.8999999999999999</span>
# <span style="color:cyan"> |-nesterov: False</span>
# <span style="color:blue"> |-num_cnn_layers: 2</span>
# <span style="color:cyan"> |-num_dense_layers: 2</span>
# <span style="color:blue"> |-num_filter_0: 48</span>
# <span style="color:cyan"> |-num_filter_1: 112</span>
# <span style="color:blue"> |-num_filter_2: 80</span>
# <span style="color:cyan"> |-num_nodes_0: 24</span>
# <span style="color:blue"> |-num_nodes_1: 32</span>
# <span style="color:cyan"> |-pooling_0: False</span>
# <span style="color:blue"> |-pooling_1: False</span>
# <span style="color:cyan"> |-pooling_2: False</span>
# <span style="color:cyan"> |-Score: 0.7716666460037231</span>
# <span style="color:cyan"> |-Best step: 0</span>

# %%
tuner.results_summary()
# Out:
# <span style="color:#4527A0"><h1 style="font-size:18px">Results summary</h1></span>
# <span style="color:cyan"> |-Results in trial3_logs\2019-11-19T11-49-39</span>
# <span style="color:cyan"> |-Showing 10 best trials</span>
# <span style="color:cyan"> |-Objective: Objective(name='acc', direction='max') Score: 0.9566666483879089</span>
# <span style="color:cyan"> |-Objective: Objective(name='acc', direction='max') Score: 0.8600000143051147</span>
# <span style="color:cyan"> |-Objective: Objective(name='acc', direction='max') Score: 0.7716666460037231</span>
# <span style="color:cyan"> |-Objective: Objective(name='acc', direction='max') Score: 0.7316666841506958</span>
# <span style="color:cyan"> |-Objective: Objective(name='acc', direction='max') Score: 0.5099999904632568</span>
